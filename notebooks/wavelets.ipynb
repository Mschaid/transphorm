# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pywt
from transphorm.model_components import SyntheticTSDataModule
import matplotlib.pyplot as plt
import numpy as np

# %%
data_module = SyntheticTSDataModule(batch_size=64)
data_module.prepare_data()
data_module.setup('train')

# %%
train = data_module.train.dataset.tensors[0].detach().numpy()
plt.plot(train[1])

# %%
coeffs, freqs = pywt.cwt(train[1], scales = [10,50,100,250,500,1000],wavelet = 'morl', sampling_period= 1)
power = (abs(coeffs)) ** 2
period = 1. / freqs
time = range(0,coeffs[0].shape[0],1)
plt.plot(train[1], color = 'k', lw = 0.5)
plt.imshow(coeffs, aspect='auto')

# %%
coeffs.shape
# Out:
# (6, 5000)

# %%
plt.plot(coeffs[1])
